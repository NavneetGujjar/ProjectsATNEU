# %% [markdown]
# <a href="https://colab.research.google.com/github/NavneetGujjar/ProjectsATNEU/blob/main/NEU_Data_Analytics_Project3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visibility Graph Method

# %%
# !pip install ts2vg
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 5.3 MB/s
# ...

# %%
# !pip install igraph
# Out:
# ...
#      |████████████████████████████████| 3.2 MB 5.3 MB/s
# ...

# %%
# !pip install pycairo
# !pip install cairocffi
# Out:
# ...
#      |████████████████████████████████| 344 kB 4.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   ERROR: Failed building wheel for pycairo
# Failed to build pycairo
# ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
# ...
#      |████████████████████████████████| 88 kB 3.3 MB/s
# ...
#   Created wheel for cairocffi: filename=cairocffi-1.3.0-py3-none-any.whl size=89667 sha256=0f80ad7f5001c919bfc646b9c1c35bbbcaf05fdf12f4a5ea10d215ece44358c2
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/e1/5c8a9692a27f639a07c949044bec943f26c81cd53d3805319f
# Successfully built cairocffi
# ...

# %%
from google.colab import files
uploaded = files.upload()

for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)

# %%
# To check the items that are being uploaded 
uploaded.items()

# %%
import io
import pandas as pd
import os as os
# Global variable for accessing, reading and loading data
# Types of csv files
types_of_data = ["walking","running","climbingup","climbingdown"]
for d_type in types_of_data:
  for i in range(1,16):
    globals()[f"acc_{d_type}_subject{i}"] = pd.read_csv(f"{d_type}_subject{i}.csv")

# %%
# accessing the data that are in uploaded files
acc_walking_subject1
acc_running_subject1
acc_climbingup_subject1
acc_climbingdown_subject1

# %%
import seaborn as sns
sns.lineplot(x=range(1, len(acc_walking_subject1['attr_x'][1000:1200])+1), y=acc_walking_subject1['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject2['attr_x'][1000:1200])+1), y=acc_walking_subject2['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject3['attr_x'][1000:1200])+1), y=acc_walking_subject3['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject4['attr_x'][1000:1200])+1), y=acc_walking_subject4['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject5['attr_x'][1000:1200])+1), y=acc_walking_subject5['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject6['attr_x'][1000:1200])+1), y=acc_walking_subject6['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject7['attr_x'][1000:1200])+1), y=acc_walking_subject7['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject8['attr_x'][1000:1200])+1), y=acc_walking_subject8['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject9['attr_x'][1000:1200])+1), y=acc_walking_subject9['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject10['attr_x'][1000:1200])+1), y=acc_walking_subject10['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject11['attr_x'][1000:1200])+1), y=acc_walking_subject11['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject12['attr_x'][1000:1200])+1), y=acc_walking_subject12['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject13['attr_x'][1000:1200])+1), y=acc_walking_subject13['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject14['attr_x'][1000:1200])+1), y=acc_walking_subject14['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_walking_subject15['attr_x'][1000:1200])+1), y=acc_walking_subject15['attr_x'][1000:1200])

# %%
sns.lineplot(x=range(1, len(acc_running_subject1['attr_x'][1000:1200])+1), y=acc_running_subject1['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_running_subject2['attr_x'][1000:1200])+1), y=acc_running_subject2['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_running_subject3['attr_x'][1000:1200])+1), y=acc_running_subject3['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_running_subject4['attr_x'][1000:1200])+1), y=acc_running_subject4['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_running_subject5['attr_x'][1000:1200])+1), y=acc_running_subject5['attr_x'][1000:1200])

# %%
sns.lineplot(x=range(1, len(acc_climbingup_subject1['attr_x'][1000:1200])+1), y=acc_climbingup_subject1['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingup_subject2['attr_x'][1000:1200])+1), y=acc_climbingup_subject2['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingup_subject3['attr_x'][1000:1200])+1), y=acc_climbingup_subject3['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingup_subject4['attr_x'][1000:1200])+1), y=acc_climbingup_subject4['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingup_subject5['attr_x'][1000:1200])+1), y=acc_climbingup_subject5['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingup_subject6['attr_x'][1000:1200])+1), y=acc_climbingup_subject6['attr_x'][1000:1200])

# %%
sns.lineplot(x=range(1, len(acc_climbingdown_subject1['attr_x'][1000:1200])+1), y=acc_climbingdown_subject1['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingdown_subject2['attr_x'][1000:1200])+1), y=acc_climbingdown_subject2['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingdown_subject3['attr_x'][1000:1200])+1), y=acc_climbingdown_subject3['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingdown_subject4['attr_x'][1000:1200])+1), y=acc_climbingdown_subject4['attr_x'][1000:1200])
sns.lineplot(x=range(1, len(acc_climbingdown_subject5['attr_x'][1000:1200])+1), y=acc_climbingdown_subject5['attr_x'][1000:1200])

# %%
from ts2vg import HorizontalVG
g = NaturalVG()
g.build(walking['attr_z'][1000:1200])
ig_g = g.as_igraph()

# %%
print('Number of Nodes:',ig_g.vcount())
print('Number of Links:',ig_g.ecount())
print('Average Degree:',np.mean(ig_g.degree()))
print('Network Diameter:',ig_g.diameter())
print('Average Path Length:',ig_g.average_path_length())
# Out:
# Number of Nodes: 200
# Number of Links: 876
# Average Degree: 8.76
# Network Diameter: 7
# Average Path Length: 3.535829145728643

# %%
from ts2vg import HorizontalVG
g = NaturalVG()
g.build(standing['attr_z'][1000:1200])
ig_g = g.as_igraph()

# %%
print('Number of Nodes:',ig_g.vcount())
print('Number of Links:',ig_g.ecount())
print('Average Degree:',np.mean(ig_g.degree()))
print('Network Diameter:',ig_g.diameter())
print('Average Path Length:',ig_g.average_path_length())
# Out:
# Number of Nodes: 200
# Number of Links: 744
# Average Degree: 7.44
# Network Diameter: 9
# Average Path Length: 3.7210552763819096
